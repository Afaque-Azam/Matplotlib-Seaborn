# %%
import matplotlib.pyplot as plt

years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
runs =  [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]

plt.bar(years,runs)
# Out:
# <BarContainer object of 10 artists>

# %%
import matplotlib.pyplot as plt

years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
runs =  [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]

plt.bar(years,runs)
plt.xlabel("Years")
plt.ylabel("Runs Scored")
plt.title("Sachin's Yearly Runs")

plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import numpy as np

years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]

sachin = [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]
sehwag = [0, 200, 900, 1400, 1600, 1800, 1500, 1100, 800, 0]
kohli  = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]

x = np.arange(len(years))
width = 0.25

plt.bar(x-width, sachin, width=width, label="Sachin")
plt.bar(x, sehwag, width=width, label="Sehwag")
plt.bar(x+width, kohli, width=width, label="Kohli")

plt.xlabel("Years")
plt.ylabel("Runs Scored")
plt.title("Runs Comparison")
plt.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np

years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]

sachin = [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]
sehwag = [0, 200, 900, 1400, 1600, 1800, 1500, 1100, 800, 0]
kohli  = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]

x = np.arange(len(years))
width = 0.25

plt.bar(x-width, sachin, width=width, label="Sachin")
plt.bar(x, sehwag, width=width, label="Sehwag")
plt.bar(x+width, kohli, width=width, label="Kohli")

plt.xlabel("Years")
plt.ylabel("Runs Scored")
plt.title("Runs Comparison")

plt.xticks(x, years)  # show actual year instead of 0,1,2....

plt.tight_layout()
plt.legend()

# %% [markdown]
# ### Horizontal bar chart

# %%
import matplotlib.pyplot as plt

subjects = ["Math", "Physics", "Chemistry", "Biology", "English"]
marks = [85, 92, 78, 88, 76]

plt.barh(subjects, marks, color="red")
plt.xlabel("Marks")
plt.ylabel("Subject")
plt.title("Marks Obtained")
plt.tight_layout()

# %% [markdown]
# #### import matplotlib.pyplot as plt
#
# players = ["Sachin", "Sehwag", "Kohli", "Yuvraj"]
# runs_5yrs = [500+700+1100+1500+1800, 0+200+900+1400+1600, 0+0+500+800+1100, 300+600+800+1100+900]
#
# plt.bar(players, runs_5yrs)
# plt.xlabel("Total Runs in First 5 Years")
# plt.title("First 5-Year Performance of Indian Batsmen")
# plt.tight_layout()

# %%
import matplotlib.pyplot as plt

players = ["Sachin", "Sehwag", "Kohli", "Yuvraj"]
runs_5yrs = [500+700+1100+1500+1800, 0+200+900+1400+1600, 0+0+500+800+1100, 300+600+800+1100+900]

plt.barh(players, runs_5yrs)     
plt.xlabel("Total Runs in First 5 Years")
plt.title("First 5-Year Performance of Indian Batsmen")
plt.tight_layout()

# %% [markdown]
# ### Adding value labels with plt.text()
#
# plt.text(x, y, "Your text here", fontsize=12, color="red")
#
# x, y → position jaha text likhna hai (data coordinates me)
#
# "Your text here" → jo message likhna hai
#
# fontsize, color, ha, va, rotation → styling ke options

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 15]

plt.plot(x, y, marker="o")

# Add text at specific points
plt.text(1, 10, "Start", color="green", fontsize=12)
plt.text(5, 15, "End", color="red", fontsize=12)
plt.text(3, 25, "Peak Point", color="blue", fontsize=12, ha="center")

plt.title("Example of plt.text()")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
import matplotlib.pyplot as plt

players = ["Sachin", "Sehwag", "Kohli", "Rohit", "Dhoni"]
runs = [1556, 2453,1256,1734,1400]

plt.bar(players, runs, color="yellowgreen")

# Add label on top of bar
for i in range(len(players)):
    plt.text(i, runs[i]+30, str(runs[i]), ha="center", color="red")

plt.xlabel("Players")
plt.ylabel("Runs Scored")
plt.title("Performance Comparison")
plt.tight_layout()
