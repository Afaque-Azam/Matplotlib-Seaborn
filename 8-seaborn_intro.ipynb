# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

sns.set_theme(style="darkgrid")

x = np.array([14,2,3,4,5,16,7,8,9,27,33,76,98,22,23,10,23,10])
y = np.sin(x)

sns.lineplot(x = x, y = y)
plt.title("Beautiful Line Plot")
plt.show()
